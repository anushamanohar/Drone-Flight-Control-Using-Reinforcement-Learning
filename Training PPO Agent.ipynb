# %% [markdown]
# ### ENVIRONMENT

# %%
"""
This is a gym environment based for the drone_game
The goal is to reach randomly positoned targets
"""

import os
from math import sin, cos, pi, sqrt
from random import randrange

import numpy as np
import gym
from gym import spaces

import pygame
from pygame.locals import *


class droneEnv(gym.Env):
    def __init__(self, render_every_frame, mouse_target):
        super(droneEnv, self).__init__()

        self.render_every_frame = render_every_frame
        # Makes the target follow the mouse
        self.mouse_target = mouse_target

        # Initialize Pygame, load sprites
        pygame.init()
        self.screen = pygame.display.set_mode((800, 800))
        self.FramePerSec = pygame.time.Clock()

        self.player = pygame.image.load(os.path.join("assets/sprites/drone_old.png"))
        self.player.convert()

        self.target = pygame.image.load(os.path.join("assets/sprites/target_old.png"))
        self.target.convert()

        pygame.font.init()
        self.myfont = pygame.font.SysFont("Comic Sans MS", 20)

        # Physics constants
        self.FPS = 60
        self.gravity = 0.08
        self.thruster_amplitude = 0.04
        self.diff_amplitude = 0.003
        self.thruster_mean = 0.04
        self.mass = 1
        self.arm = 25

        # Initialize variables
        (self.a, self.ad, self.add) = (0, 0, 0)
        (self.x, self.xd, self.xdd) = (400, 0, 0)
        (self.y, self.yd, self.ydd) = (400, 0, 0)
        self.xt = randrange(200, 600)
        self.yt = randrange(200, 600)

        # Initialize game variables
        self.target_counter = 0
        self.reward = 0
        self.time = 0
        self.time_limit = 20
        if self.mouse_target is True:
            self.time_limit = 1000

        # 2 action thrust amplitude and thrust difference in float values between -1 and 1
        self.action_space = spaces.Box(low=-1, high=1, shape=(2,))
        # 6 observations: angle_to_up, velocity, angle_velocity, distance_to_target, angle_to_target, angle_target_and_velocity
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(6,))

    def reset(self):
        # Reset variables
        (self.a, self.ad, self.add) = (0, 0, 0)
        (self.x, self.xd, self.xdd) = (400, 0, 0)
        (self.y, self.yd, self.ydd) = (400, 0, 0)
        self.xt = randrange(200, 600)
        self.yt = randrange(200, 600)

        self.target_counter = 0
        self.reward = 0
        self.time = 0

        return self.get_obs()

    def get_obs(self) -> np.ndarray:
        """
        Calculates the observations

        Returns:
            np.ndarray: The normalized observations:
            - angle_to_up : angle between the drone and the up vector (to observe gravity)
            - velocity : velocity of the drone
            - angle_velocity : angle of the velocity vector
            - distance_to_target : distance to the target
            - angle_to_target : angle between the drone and the target
            - angle_target_and_velocity : angle between the to_target vector and the velocity vector
        """
        angle_to_up = self.a / 180 * pi
        velocity = sqrt(self.xd**2 + self.yd**2)
        angle_velocity = self.ad
        distance_to_target = (
            sqrt((self.xt - self.x) ** 2 + (self.yt - self.y) ** 2) / 500
        )
        angle_to_target = np.arctan2(self.yt - self.y, self.xt - self.x)
        # Angle between the to_target vector and the velocity vector
        angle_target_and_velocity = np.arctan2(
            self.yt - self.y, self.xt - self.x
        ) - np.arctan2(self.yd, self.xd)
        distance_to_target = (
            sqrt((self.xt - self.x) ** 2 + (self.yt - self.y) ** 2) / 500
        )
        return np.array(
            [
                angle_to_up,
                velocity,
                angle_velocity,
                distance_to_target,
                angle_to_target,
                angle_target_and_velocity,
            ]
        ).astype(np.float32)

    def step(self, action):
        # Game loop
        self.reward = 0.0
        (action0, action1) = (action[0], action[1])

        # Act every 5 frames
        for _ in range(5):
            self.time += 1 / 60

            if self.mouse_target is True:
                self.xt, self.yt = pygame.mouse.get_pos()

            # Initialize accelerations
            self.xdd = 0
            self.ydd = self.gravity
            self.add = 0
            thruster_left = self.thruster_mean
            thruster_right = self.thruster_mean

            thruster_left += action0 * self.thruster_amplitude
            thruster_right += action0 * self.thruster_amplitude
            thruster_left += action1 * self.diff_amplitude
            thruster_right -= action1 * self.diff_amplitude

            # Calculating accelerations with Newton's laws of motions
            self.xdd += (
                -(thruster_left + thruster_right) * sin(self.a * pi / 180) / self.mass
            )
            self.ydd += (
                -(thruster_left + thruster_right) * cos(self.a * pi / 180) / self.mass
            )
            self.add += self.arm * (thruster_right - thruster_left) / self.mass

            self.xd += self.xdd
            self.yd += self.ydd
            self.ad += self.add
            self.x += self.xd
            self.y += self.yd
            self.a += self.ad

            dist = sqrt((self.x - self.xt) ** 2 + (self.y - self.yt) ** 2)

            # Reward per step survived
            self.reward += 1 / 60
            # Penalty according to the distance to target
            self.reward -= dist / (100 * 60)

            if dist < 50:
                # Reward if close to target
                self.xt = randrange(200, 600)
                self.yt = randrange(200, 600)
                self.reward += 100
                
                
                #
                self.target_counter+=1

            # If out of time
            if self.time > self.time_limit:
                done = True
                break

            # If too far from target (crash)
            elif dist > 1000:
                self.reward -= 1000
                done = True
                break

            else:
                done = False

            if self.render_every_frame is True:
                self.render("yes")

        info = {}

        return (
            self.get_obs(),
            self.reward,
            done,
            info,
        )

    def render(self, mode):
        # Pygame rendering
        pygame.event.get()
        self.screen.fill(0)
        self.screen.blit(
            self.target,
            (
                self.xt - int(self.target.get_width() / 2),
                self.yt - int(self.target.get_height() / 2),
            ),
        )
        player_copy = pygame.transform.rotate(self.player, self.a)
        self.screen.blit(
            player_copy,
            (
                self.x - int(player_copy.get_width() / 2),
                self.y - int(player_copy.get_height() / 2),
            ),
        )

        textsurface = self.myfont.render(
            "Collected: " + str(self.target_counter), False, (255, 255, 255)
        )
        self.screen.blit(textsurface, (20, 20))
        textsurface3 = self.myfont.render(
            "Time: " + str(int(self.time)), False, (255, 255, 255)
        )
        self.screen.blit(textsurface3, (20, 50))

        pygame.display.update()
        self.FramePerSec.tick(self.FPS)

    def close(self):
        pass

# %% [markdown]
# ## TEST ENVIRONMENT WORKING

# %%
env = droneEnv(True, False)

obs = env.reset()
env.render("yes")

print("Observation space:")
print(env.observation_space)
print("")
print("Action space:")
print(env.action_space)
print("")
print("Action space sample:")
print(env.action_space.sample())

# Choose an action to execute n_steps times
action = np.array([0.0, 1.0])
n_steps = 10
for step in range(n_steps):
    print("Step {}".format(step + 1))
    obs, reward, done, info = env.step(action)
    print("obs=", obs, "reward=", reward, "done=", done)
    env.render("yes")
    if done:
        print("Done!", "reward=", reward)
        break
# Out:
# Observation space:
# Box([-inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf], (6,), float32)
#
# Action space:
# Box([-1. -1.], [1. 1.], (2,), float32)
#
# Action space sample:
# [0.69754815 0.47666866]
# Step 1
# obs= [-0.03926991  0.00418868 -0.75        0.5318017   0.8013739   0.79181826] reward= -0.13825362982355913 done= False
# Step 2
# obs= [-0.14398967  0.03454228 -1.5         0.5316636   0.80162644  0.7626214 ] reward= -0.13822441168881405 done= False
# Step 3
# obs= [-0.31415927  0.1170206  -2.25        0.53107655  0.8026165   0.7145571 ] reward= -0.13806922357633705 done= False
# Step 4
# obs= [-0.5497787   0.27655566 -3.          0.52946705  0.80502886  0.6484174 ] reward= -0.13759285149245498 done= False
# Step 5
# obs= [-0.850848    0.53502405 -3.75        0.5259651   0.8095198   0.56514055] reward= -0.13648331002542924 done= False
# Step 6
# obs= [-1.2173672   0.907548   -4.5         0.5194007   0.8164096   0.46564546] reward= -0.13430199893417313 done= False
# Step 7
# obs= [-1.6493361   1.3969848  -5.25        0.50839406  0.82528543  0.35064107] reward= -0.1305037956412159 done= False
# Step 8
# obs= [-2.146755    1.9871436  -6.          0.49159113  0.83454573  0.22048162] reward= -0.12450954263282686 done= False
# Step 9
# obs= [-2.7096236   2.6364434  -6.75        0.46806988  0.8409606   0.07522332] reward= -0.11584687994765386 done= False
# Step 10
# obs= [-3.3379421   3.275448   -7.5         0.43786743  0.8394233  -0.08479071] reward= -0.10435322105740458 done= False

# %% [markdown]
# ## TRAIN PPO AGENT

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
import wandb
from wandb.integration.sb3 import WandbCallback


run = wandb.init(
    project="CSP",
    sync_tensorboard=True,
    monitor_gym=True,
)

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = droneEnv(False, False)
env = Monitor(env, log_dir)

# Create TD agent
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_dir)



training_steps = 1_000_000

# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=training_steps, save_path=log_dir, name_prefix="ppo_model_v6"
)

# Train the agent
model.learn(
    total_timesteps=training_steps,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=100,
            model_save_path=f"models/{run.id}",
            model_save_freq=training_steps,
            verbose=2,
        ),
    ],
)
# Out:
# Finishing last run (ID:i1um6j59) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">sparkling-pyramid-67</strong> at: <a href='https://wandb.ai/cs5180/CSP/runs/i1um6j59' target="_blank">https://wandb.ai/cs5180/CSP/runs/i1um6j59</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231209_144426-i1um6j59\logs</code>
# Successfully finished last run (ID:i1um6j59). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.10
# Run data is saved locally in <code>C:\Users\AVISH\wandb\run-20231209_172614-5kda4cwh</code>
# Syncing run <strong><a href='https://wandb.ai/cs5180/CSP/runs/5kda4cwh' target="_blank">helpful-yogurt-68</a></strong> to <a href='https://wandb.ai/cs5180/CSP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cs5180/CSP' target="_blank">https://wandb.ai/cs5180/CSP</a>
#  View run at <a href='https://wandb.ai/cs5180/CSP/runs/5kda4cwh' target="_blank">https://wandb.ai/cs5180/CSP/runs/5kda4cwh</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to tmp/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.5     |
# |    ep_rew_mean     | -991     |
# | time/              |          |
# |    fps             | 712      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.9         |
# |    ep_rew_mean          | -985         |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0040013473 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.00116      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+05     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 1.01         |
# |    value_loss           | 2.02e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.4         |
# |    ep_rew_mean          | -979         |
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0033069965 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.37e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00267     |
# |    std                  | 1.01         |
# |    value_loss           | 2.06e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.3         |
# |    ep_rew_mean          | -979         |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 4            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0053875437 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.00581      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00419     |
# |    std                  | 1.01         |
# |    value_loss           | 1.99e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.3         |
# |    ep_rew_mean          | -987         |
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0027419073 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0029       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.24e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 1            |
# |    value_loss           | 1.91e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.7       |
# |    ep_rew_mean          | -992       |
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 6          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00395866 |
# |    clip_fraction        | 0.0267     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.85      |
# |    explained_variance   | 0.00161    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.16e+05   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00317   |
# |    std                  | 1.01       |
# |    value_loss           | 1.86e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.2         |
# |    ep_rew_mean          | -985         |
# | time/                   |              |
# |    fps                  | 352          |
# |    iterations           | 7            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0034848088 |
# |    clip_fraction        | 0.00815      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.000921     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.11e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 1.01         |
# |    value_loss           | 1.76e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.1         |
# |    ep_rew_mean          | -983         |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 8            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0052214544 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.000649     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00412     |
# |    std                  | 1.03         |
# |    value_loss           | 1.88e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.2        |
# |    ep_rew_mean          | -989        |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 9           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005955471 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.000397    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.22e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00507    |
# |    std                  | 1.04        |
# |    value_loss           | 1.71e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.9         |
# |    ep_rew_mean          | -991         |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 10           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0048770155 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.000324     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.81e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00639     |
# |    std                  | 1.05         |
# |    value_loss           | 1.71e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.9         |
# |    ep_rew_mean          | -988         |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 11           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0044342554 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.000243     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.07e+04     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 1.05         |
# |    value_loss           | 1.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.4         |
# |    ep_rew_mean          | -985         |
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 12           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0056151142 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.000193     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0048      |
# |    std                  | 1.07         |
# |    value_loss           | 1.63e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.3        |
# |    ep_rew_mean          | -992        |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 13          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005728525 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.000176    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00402    |
# |    std                  | 1.08        |
# |    value_loss           | 1.66e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.5        |
# |    ep_rew_mean          | -987        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 14          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.003983668 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.000131    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.35e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00362    |
# |    std                  | 1.09        |
# |    value_loss           | 1.68e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.7        |
# |    ep_rew_mean          | -988        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 15          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004726632 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.000104    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.41e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00397    |
# |    std                  | 1.11        |
# |    value_loss           | 1.59e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.9         |
# |    ep_rew_mean          | -987         |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 16           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0041664643 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 9.52e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.52e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00439     |
# |    std                  | 1.1          |
# |    value_loss           | 1.57e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.6        |
# |    ep_rew_mean          | -983        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 17          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003376531 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 7.39e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.29e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00321    |
# |    std                  | 1.11        |
# |    value_loss           | 1.54e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.2        |
# |    ep_rew_mean          | -985        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 18          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004684824 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 4.85e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.53e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00531    |
# |    std                  | 1.11        |
# |    value_loss           | 1.42e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.9        |
# |    ep_rew_mean          | -991        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 19          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004197186 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 5.33e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.73e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 1.11        |
# |    value_loss           | 1.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | -985        |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 20          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005374747 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 3.53e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.6e+04     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 1.12        |
# |    value_loss           | 1.44e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | -979        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 21          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005179163 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 3.83e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.72e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0046     |
# |    std                  | 1.12        |
# |    value_loss           | 1.49e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.7         |
# |    ep_rew_mean          | -983         |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 22           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0039731143 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 3.34e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.77e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 1.12         |
# |    value_loss           | 1.45e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.2        |
# |    ep_rew_mean          | -989        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 23          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004901386 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 2.84e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.88e+04    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00443    |
# |    std                  | 1.13        |
# |    value_loss           | 1.31e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.9       |
# |    ep_rew_mean          | -995       |
# | time/                   |            |
# |    fps                  | 365        |
# |    iterations           | 24         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00387323 |
# |    clip_fraction        | 0.0301     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 2.65e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.38e+04   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00315   |
# |    std                  | 1.13       |
# |    value_loss           | 1.41e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43           |
# |    ep_rew_mean          | -994         |
# | time/                   |              |
# |    fps                  | 365          |
# |    iterations           | 25           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0027860869 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 2.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.59e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00384     |
# |    std                  | 1.13         |
# |    value_loss           | 1.33e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.9         |
# |    ep_rew_mean          | -990         |
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 26           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0046669026 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 1.73e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.16e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0059      |
# |    std                  | 1.14         |
# |    value_loss           | 1.33e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.9        |
# |    ep_rew_mean          | -988        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 27          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003465043 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 1.62e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.13e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00292    |
# |    std                  | 1.14        |
# |    value_loss           | 1.32e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.5         |
# |    ep_rew_mean          | -995         |
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 28           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0035877733 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 1.52e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.37e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00232     |
# |    std                  | 1.15         |
# |    value_loss           | 1.26e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.4        |
# |    ep_rew_mean          | -994        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 29          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004978488 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 1.15e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.06e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00352    |
# |    std                  | 1.16        |
# |    value_loss           | 1.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | -998        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 30          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004235019 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 1.19e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 1.16        |
# |    value_loss           | 1.21e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.8         |
# |    ep_rew_mean          | -993         |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 31           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0051123113 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 9.48e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.48e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00501     |
# |    std                  | 1.17         |
# |    value_loss           | 1.19e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.4         |
# |    ep_rew_mean          | -988         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 32           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0032566881 |
# |    clip_fraction        | 0.00981      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 9e-06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.13e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00173     |
# |    std                  | 1.17         |
# |    value_loss           | 1.22e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.8        |
# |    ep_rew_mean          | -993        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 33          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004682987 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 7.51e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.29e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00555    |
# |    std                  | 1.18        |
# |    value_loss           | 1.14e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.4       |
# |    ep_rew_mean          | -986       |
# | time/                   |            |
# |    fps                  | 368        |
# |    iterations           | 34         |
# |    time_elapsed         | 188        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00473467 |
# |    clip_fraction        | 0.0333     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 8.34e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.55e+04   |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0039    |
# |    std                  | 1.17       |
# |    value_loss           | 1.1e+05    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.4         |
# |    ep_rew_mean          | -981         |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 35           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0035768915 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 6.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.96e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 1.17         |
# |    value_loss           | 1.15e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.7         |
# |    ep_rew_mean          | -983         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 36           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0042329044 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 7.51e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.07e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0037      |
# |    std                  | 1.19         |
# |    value_loss           | 1.09e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44           |
# |    ep_rew_mean          | -985         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 37           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0041491333 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 6.08e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.55e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00252     |
# |    std                  | 1.19         |
# |    value_loss           | 1.06e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.8         |
# |    ep_rew_mean          | -989         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 38           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0036581086 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 6.56e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.64e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0026      |
# |    std                  | 1.18         |
# |    value_loss           | 1.07e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.4        |
# |    ep_rew_mean          | -986        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 39          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005953706 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 7.15e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.56e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00591    |
# |    std                  | 1.18        |
# |    value_loss           | 1.1e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.2         |
# |    ep_rew_mean          | -979         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 40           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0043473644 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 4.89e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.41e+04     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 1.17         |
# |    value_loss           | 1.08e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.4         |
# |    ep_rew_mean          | -986         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 41           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0032719802 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 5.01e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.79e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00354     |
# |    std                  | 1.17         |
# |    value_loss           | 1.04e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.3         |
# |    ep_rew_mean          | -988         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 42           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0051615946 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 4.83e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.88e+04     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00467     |
# |    std                  | 1.18         |
# |    value_loss           | 9.54e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | -981        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 43          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004052928 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 4.53e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.3e+04     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0045     |
# |    std                  | 1.19        |
# |    value_loss           | 9.77e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.8         |
# |    ep_rew_mean          | -981         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 44           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0032429253 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 4.95e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.2e+04      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 1.19         |
# |    value_loss           | 8.98e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -981        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 45          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004948632 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 1.62e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.16e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00502    |
# |    std                  | 1.18        |
# |    value_loss           | 8.6e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.3         |
# |    ep_rew_mean          | -979         |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 46           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0052708536 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 1.18e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.54e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00458     |
# |    std                  | 1.19         |
# |    value_loss           | 8.89e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.1         |
# |    ep_rew_mean          | -974         |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 47           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0049305884 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 3.21e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00467     |
# |    std                  | 1.19         |
# |    value_loss           | 8.08e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.3         |
# |    ep_rew_mean          | -971         |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 48           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0051512364 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.00449      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00377     |
# |    std                  | 1.19         |
# |    value_loss           | 8.49e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.3         |
# |    ep_rew_mean          | -982         |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 49           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0059252507 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.000302     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.38e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00593     |
# |    std                  | 1.21         |
# |    value_loss           | 7.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.7         |
# |    ep_rew_mean          | -982         |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 50           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0029395667 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.00726      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.75e+04     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00261     |
# |    std                  | 1.19         |
# |    value_loss           | 7.04e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.6         |
# |    ep_rew_mean          | -976         |
# | time/                   |              |
# ...
# | train/                  |             |
# |    approx_kl            | 0.012616947 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 841         |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.00614    |
# |    std                  | 0.36        |
# |    value_loss           | 2.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 963         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 477         |
# |    time_elapsed         | 2781        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.016883314 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 660         |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.00169    |
# |    std                  | 0.359       |
# |    value_loss           | 2.69e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 975         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 478         |
# |    time_elapsed         | 2786        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.018091137 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.361       |
# |    value_loss           | 2.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 953         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 479         |
# |    time_elapsed         | 2791        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.012817298 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00518    |
# |    std                  | 0.363       |
# |    value_loss           | 3.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 938         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 480         |
# |    time_elapsed         | 2795        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.008102506 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.62e+03    |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0034     |
# |    std                  | 0.365       |
# |    value_loss           | 4.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 919         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 481         |
# |    time_elapsed         | 2800        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.009349114 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61e+03    |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.365       |
# |    value_loss           | 3.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 924         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 482         |
# |    time_elapsed         | 2805        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.011089997 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.000924   |
# |    std                  | 0.363       |
# |    value_loss           | 2.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 913         |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 483         |
# |    time_elapsed         | 2810        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.017857622 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34e+03    |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00681    |
# |    std                  | 0.366       |
# |    value_loss           | 2.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 903         |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 484         |
# |    time_elapsed         | 2814        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.013992753 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 585         |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00141    |
# |    std                  | 0.364       |
# |    value_loss           | 3e+03       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 903         |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 485         |
# |    time_elapsed         | 2819        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.014739056 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 838         |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 0.366       |
# |    value_loss           | 3.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 910         |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 486         |
# |    time_elapsed         | 2824        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.014975166 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+03    |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.00387    |
# |    std                  | 0.366       |
# |    value_loss           | 2.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 915         |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 487         |
# |    time_elapsed         | 2829        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.013311695 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00915    |
# |    std                  | 0.364       |
# |    value_loss           | 3.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 915         |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 488         |
# |    time_elapsed         | 2833        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.012937615 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3e+03     |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.0022     |
# |    std                  | 0.367       |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7812\3842415197.py in <module>
#      33
#      34 # Train the agent
# ---> 35 model.learn(
#      36     total_timesteps=training_steps,
#      37     callback=[
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305     ) -> SelfPPO:
#     306
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     246         while self.num_timesteps < total_timesteps:
#     247
# --> 248             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     249
#     250             if continue_training is False:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     179             # Give access to local variables
#     180             callback.update_locals(locals())
# --> 181             if callback.on_step() is False:
#     182                 return False
#     183
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\callbacks.py in on_step(self)
#      98         self.num_timesteps = self.model.num_timesteps
#      99
# --> 100         return self._on_step()
#     101
#     102     def on_training_end(self) -> None:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\callbacks.py in _on_step(self)
#     202         for callback in self.callbacks:
#     203             # Return False (stop training) if at least one callback returns False
# --> 204             continue_training = callback.on_step() and continue_training
#     205         return continue_training
#     206
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\callbacks.py in on_step(self)
#      98         self.num_timesteps = self.model.num_timesteps
#      99
# --> 100         return self._on_step()
#     101
#     102     def on_training_end(self) -> None:
#
# ~\anaconda3\lib\site-packages\wandb\integration\sb3\sb3.py in _on_step(self)
#     140             if self.model_save_path is not None:
#     141                 if self.n_calls % self.model_save_freq == 0:
# --> 142                     self.save_model()
#     143         return True
#     144
#
# ~\anaconda3\lib\site-packages\wandb\integration\sb3\sb3.py in save_model(self)
#     149     def save_model(self) -> None:
#     150         self.model.save(self.path)
# --> 151         wandb.save(self.path, base_path=self.model_save_path)
#     152         if self.verbose > 1:
#     153             logger.info(f"Saving model checkpoint to {self.path}")
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in wrapper_fn(self, *args, **kwargs)
#     368             def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     369                 if not getattr(self, "_is_finished", False):
# --> 370                     return func(self, *args, **kwargs)
#     371
#     372                 default_message = (
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in wrapper(self, *args, **kwargs)
#     358                     raise e
#     359                 cls._is_attaching = ""
# --> 360             return func(self, *args, **kwargs)
#     361
#     362         return wrapper
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in save(self, glob_str, base_path, policy)
#    1822             return True
#    1823
# -> 1824         return self._save(glob_str, base_path, policy)
#    1825
#    1826     def _save(
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in _save(self, glob_str, base_path, policy)
#    1876                 os.symlink(abs_path, wandb_path)
#    1877             elif not os.path.exists(wandb_path):
# -> 1878                 os.symlink(abs_path, wandb_path)
#    1879             files.append(wandb_path)
#    1880         if warn:
#
# OSError: [WinError 1314] A required privilege is not held by the client: 'C:\\Users\\AVISH\\models\\5kda4cwh\\model.zip' -> 'C:\\Users\\AVISH\\wandb\\run-20231209_172614-5kda4cwh\\files\\model.zip'

# %% [markdown]
# ## TEST TRAINED AGENT IN THE ENVIRONMENT

# %%
import torch as th
from stable_baselines3 import PPO
MODEL_PATH =r"C:\Users\AVISH\tmp\ppo_model_v1_1000000_steps.zip"

# Create and wrap the environment
env = droneEnv(True, False)

# Load the trained agent
model = PPO.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs = env.reset()
    done = False
    episode_reward = 0
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        episode_reward += reward
    print("Episode reward", episode_reward)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode reward 982.158490281774
# Episode reward 1087.0984967706584
# Episode reward 882.398535159258
# Episode reward 781.6807484924246
# Episode reward 777.6349398393277
