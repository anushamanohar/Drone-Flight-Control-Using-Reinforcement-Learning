# %% [markdown]
# ### ENVIRONMENT

# %%
"""
This is a gym environment based for the drone_game
The goal is to reach randomly positoned targets
"""

import os
from math import sin, cos, pi, sqrt
from random import randrange

import numpy as np
import gym
from gym import spaces

import pygame
from pygame.locals import *


class droneEnv(gym.Env):
    def __init__(self, render_every_frame, mouse_target):
        super(droneEnv, self).__init__()

        self.render_every_frame = render_every_frame
        # Makes the target follow the mouse
        self.mouse_target = mouse_target

        # Initialize Pygame, load sprites
        pygame.init()
        self.screen = pygame.display.set_mode((800, 800))
        self.FramePerSec = pygame.time.Clock()

        self.player = pygame.image.load(os.path.join("assets/sprites/drone_old.png"))
        self.player.convert()

        self.target = pygame.image.load(os.path.join("assets/sprites/target_old.png"))
        self.target.convert()

        pygame.font.init()
        self.myfont = pygame.font.SysFont("Comic Sans MS", 20)

        # Physics constants
        self.FPS = 60
        self.gravity = 0.08
        self.thruster_amplitude = 0.04
        self.diff_amplitude = 0.003
        self.thruster_mean = 0.04
        self.mass = 1
        self.arm = 25

        # Initialize variables
        (self.a, self.ad, self.add) = (0, 0, 0)
        (self.x, self.xd, self.xdd) = (400, 0, 0)
        (self.y, self.yd, self.ydd) = (400, 0, 0)
        self.xt = randrange(200, 600)
        self.yt = randrange(200, 600)

        # Initialize game variables
        self.target_counter = 0
        self.reward = 0
        self.time = 0
        self.time_limit = 20
        if self.mouse_target is True:
            self.time_limit = 1000

        # 2 action thrust amplitude and thrust difference in float values between -1 and 1
        self.action_space = spaces.Box(low=-1, high=1, shape=(2,))
        # 6 observations: angle_to_up, velocity, angle_velocity, distance_to_target, angle_to_target, angle_target_and_velocity
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(6,))

    def reset(self):
        # Reset variables
        (self.a, self.ad, self.add) = (0, 0, 0)
        (self.x, self.xd, self.xdd) = (400, 0, 0)
        (self.y, self.yd, self.ydd) = (400, 0, 0)
        self.xt = randrange(200, 600)
        self.yt = randrange(200, 600)

        self.target_counter = 0
        self.reward = 0
        self.time = 0

        return self.get_obs()

    def get_obs(self) -> np.ndarray:
        """
        Calculates the observations

        Returns:
            np.ndarray: The normalized observations:
            - angle_to_up : angle between the drone and the up vector (to observe gravity)
            - velocity : velocity of the drone
            - angle_velocity : angle of the velocity vector
            - distance_to_target : distance to the target
            - angle_to_target : angle between the drone and the target
            - angle_target_and_velocity : angle between the to_target vector and the velocity vector
        """
        angle_to_up = self.a / 180 * pi
        velocity = sqrt(self.xd**2 + self.yd**2)
        angle_velocity = self.ad
        distance_to_target = (
            sqrt((self.xt - self.x) ** 2 + (self.yt - self.y) ** 2) / 500
        )
        angle_to_target = np.arctan2(self.yt - self.y, self.xt - self.x)
        # Angle between the to_target vector and the velocity vector
        angle_target_and_velocity = np.arctan2(
            self.yt - self.y, self.xt - self.x
        ) - np.arctan2(self.yd, self.xd)
        distance_to_target = (
            sqrt((self.xt - self.x) ** 2 + (self.yt - self.y) ** 2) / 500
        )
        return np.array(
            [
                angle_to_up,
                velocity,
                angle_velocity,
                distance_to_target,
                angle_to_target,
                angle_target_and_velocity,
            ]
        ).astype(np.float32)

    def step(self, action):
        # Game loop
        self.reward = 0.0
        (action0, action1) = (action[0], action[1])

        # Act every 5 frames
        for _ in range(5):
            self.time += 1 / 60

            if self.mouse_target is True:
                self.xt, self.yt = pygame.mouse.get_pos()

            # Initialize accelerations
            self.xdd = 0
            self.ydd = self.gravity
            self.add = 0
            thruster_left = self.thruster_mean
            thruster_right = self.thruster_mean

            thruster_left += action0 * self.thruster_amplitude
            thruster_right += action0 * self.thruster_amplitude
            thruster_left += action1 * self.diff_amplitude
            thruster_right -= action1 * self.diff_amplitude

            # Calculating accelerations with Newton's laws of motions
            self.xdd += (
                -(thruster_left + thruster_right) * sin(self.a * pi / 180) / self.mass
            )
            self.ydd += (
                -(thruster_left + thruster_right) * cos(self.a * pi / 180) / self.mass
            )
            self.add += self.arm * (thruster_right - thruster_left) / self.mass

            self.xd += self.xdd
            self.yd += self.ydd
            self.ad += self.add
            self.x += self.xd
            self.y += self.yd
            self.a += self.ad

            dist = sqrt((self.x - self.xt) ** 2 + (self.y - self.yt) ** 2)

            # Reward per step survived
            self.reward += 1 / 60
            # Penalty according to the distance to target
            self.reward -= dist / (100 * 60)

            if dist < 50:
                # Reward if close to target
                self.xt = randrange(200, 600)
                self.yt = randrange(200, 600)
                self.reward += 100
                
                
                #
                self.target_counter+=1

            # If out of time
            if self.time > self.time_limit:
                done = True
                break

            # If too far from target (crash)
            elif dist > 1000:
                self.reward -= 1000
                done = True
                break

            else:
                done = False

            if self.render_every_frame is True:
                self.render("yes")

        info = {}

        return (
            self.get_obs(),
            self.reward,
            done,
            info,
        )

    def render(self, mode):
        # Pygame rendering
        pygame.event.get()
        self.screen.fill(0)
        self.screen.blit(
            self.target,
            (
                self.xt - int(self.target.get_width() / 2),
                self.yt - int(self.target.get_height() / 2),
            ),
        )
        player_copy = pygame.transform.rotate(self.player, self.a)
        self.screen.blit(
            player_copy,
            (
                self.x - int(player_copy.get_width() / 2),
                self.y - int(player_copy.get_height() / 2),
            ),
        )

        textsurface = self.myfont.render(
            "Collected: " + str(self.target_counter), False, (255, 255, 255)
        )
        self.screen.blit(textsurface, (20, 20))
        textsurface3 = self.myfont.render(
            "Time: " + str(int(self.time)), False, (255, 255, 255)
        )
        self.screen.blit(textsurface3, (20, 50))

        pygame.display.update()
        self.FramePerSec.tick(self.FPS)

    def close(self):
        pass

# %% [markdown]
# ## TEST ENVIRONMENT WORKING

# %%
env = droneEnv(True, False)

obs = env.reset()
env.render("yes")

print("Observation space:")
print(env.observation_space)
print("")
print("Action space:")
print(env.action_space)
print("")
print("Action space sample:")
print(env.action_space.sample())

# Choose an action to execute n_steps times
action = np.array([0.0, 1.0])
n_steps = 10
for step in range(n_steps):
    print("Step {}".format(step + 1))
    obs, reward, done, info = env.step(action)
    print("obs=", obs, "reward=", reward, "done=", done)
    env.render("yes")
    if done:
        print("Done!", "reward=", reward)
        break
# Out:
# Observation space:
# Box([-inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf], (6,), float32)
#
# Action space:
# Box([-1. -1.], [1. 1.], (2,), float32)
#
# Action space sample:
# [ 0.39743373 -0.84471196]
# Step 1
# obs= [-0.03926991  0.00418868 -0.75        0.12176462  2.4027543   2.3931987 ] reward= 0.03260112590763964 done= False
# Step 2
# obs= [-0.14398967  0.03454228 -1.5         0.12190311  2.4038532   2.3648481 ] reward= 0.03257146751646054 done= False
# Step 3
# obs= [-0.31415927  0.1170206  -2.25        0.12244841  2.4085126   2.3204532 ] reward= 0.03242365841406434 done= False
# Step 4
# obs= [-0.5497787   0.27655566 -3.          0.12379135  2.421157    2.2645454 ] reward= 0.032011134430318694 done= False
# Step 5
# obs= [-0.850848    0.53502405 -3.75        0.12635559  2.4480414   2.2036622 ] reward= 0.031160051441842983 done= False
# Step 6
# obs= [-1.2173672   0.907548   -4.5         0.13052404  2.4964764   2.1457124 ] reward= 0.029702167775983026 done= False
# Step 7
# obs= [-1.6493361  1.3969848 -5.25       0.1366137  2.5731828  2.0985384] reward= 0.02749475078319589 done= False
# Step 8
# obs= [-2.146755   1.9871436 -6.         0.1449181  2.6821413  2.0680773] reward= 0.024413883568444348 done= False
# Step 9
# obs= [-2.7096236   2.6364434  -6.75        0.15577193  2.8226452   2.056908  ] reward= 0.020328487169072595 done= False
# Step 10
# obs= [-3.3379421   3.275448   -7.5         0.16953968  2.9883068   2.0640929 ] reward= 0.015089082500110729 done= False

# %% [markdown]
# ## TRAIN SAC AGENT

# %%
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
import wandb
from wandb.integration.sb3 import WandbCallback


run = wandb.init(
    project="CSP",
    sync_tensorboard=True,
    monitor_gym=True,
)

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = droneEnv(False, False)
env = Monitor(env, log_dir)

# Create SAC agent
model = SAC("MlpPolicy", env, verbose=1, tensorboard_log=log_dir)

training_steps = 1_000_000


# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=training_steps, save_path=log_dir, name_prefix="sac_model_v5"
)

# Train the agent
model.learn(
    total_timesteps=training_steps,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=training_steps,
            model_save_path=f"models/{run.id}",
            model_save_freq=training_steps,
            verbose=2,
        ),
    ],
)
# Out:
# Finishing last run (ID:agzckh4w) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">polar-tree-71</strong> at: <a href='https://wandb.ai/cs5180/CSP/runs/agzckh4w' target="_blank">https://wandb.ai/cs5180/CSP/runs/agzckh4w</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231210_054945-agzckh4w\logs</code>
# Successfully finished last run (ID:agzckh4w). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.10
# Run data is saved locally in <code>C:\Users\AVISH\wandb\run-20231210_143604-nc0cqlss</code>
# Syncing run <strong><a href='https://wandb.ai/cs5180/CSP/runs/nc0cqlss' target="_blank">rosy-totem-73</a></strong> to <a href='https://wandb.ai/cs5180/CSP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cs5180/CSP' target="_blank">https://wandb.ai/cs5180/CSP</a>
#  View run at <a href='https://wandb.ai/cs5180/CSP/runs/nc0cqlss' target="_blank">https://wandb.ai/cs5180/CSP/runs/nc0cqlss</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to tmp/SAC_4
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 41.8      |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 145       |
# |    time_elapsed    | 1         |
# |    total_timesteps | 167       |
# | train/             |           |
# |    actor_loss      | 13.2      |
# |    critic_loss     | 1.48e+04  |
# |    ent_coef        | 0.981     |
# |    ent_coef_loss   | -0.0654   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 66        |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 39.5      |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 90        |
# |    time_elapsed    | 3         |
# |    total_timesteps | 316       |
# | train/             |           |
# |    actor_loss      | 40.8      |
# |    critic_loss     | 3.04e+04  |
# |    ent_coef        | 0.941     |
# |    ent_coef_loss   | -0.132    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 215       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37.7      |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 79        |
# |    time_elapsed    | 5         |
# |    total_timesteps | 452       |
# | train/             |           |
# |    actor_loss      | 61.9      |
# |    critic_loss     | 2.21e+04  |
# |    ent_coef        | 0.917     |
# |    ent_coef_loss   | -0.0744   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 351       |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.2     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 612      |
# | train/             |          |
# |    actor_loss      | 72.7     |
# |    critic_loss     | 1.06e+04 |
# |    ent_coef        | 0.9      |
# |    ent_coef_loss   | -0.0675  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.5     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 71       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 771      |
# | train/             |          |
# |    actor_loss      | 88       |
# |    critic_loss     | 8.34e+03 |
# |    ent_coef        | 0.891    |
# |    ent_coef_loss   | 0.00597  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 670      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.6     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 68       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 926      |
# | train/             |          |
# |    actor_loss      | 114      |
# |    critic_loss     | 5.3e+03  |
# |    ent_coef        | 0.889    |
# |    ent_coef_loss   | -0.0249  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 825      |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 41.2      |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 65        |
# |    time_elapsed    | 17        |
# |    total_timesteps | 1155      |
# | train/             |           |
# |    actor_loss      | 119       |
# |    critic_loss     | 2.52e+03  |
# |    ent_coef        | 0.892     |
# |    ent_coef_loss   | 0.00178   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1054      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.9     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 64       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1278     |
# | train/             |          |
# |    actor_loss      | 103      |
# |    critic_loss     | 7.18e+03 |
# |    ent_coef        | 0.895    |
# |    ent_coef_loss   | -0.0372  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1177     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.8     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 63       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1396     |
# | train/             |          |
# |    actor_loss      | 161      |
# |    critic_loss     | 8.29e+03 |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | -0.00898 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1295     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 62       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1510     |
# | train/             |          |
# |    actor_loss      | 203      |
# |    critic_loss     | 5.34e+03 |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | 0.0382   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1409     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.9     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 61       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1623     |
# | train/             |          |
# |    actor_loss      | 187      |
# |    critic_loss     | 1.66e+03 |
# |    ent_coef        | 0.898    |
# |    ent_coef_loss   | -0.0241  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1522     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 61       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1737     |
# | train/             |          |
# |    actor_loss      | 220      |
# |    critic_loss     | 3.58e+03 |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | 0.00448  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1636     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | -993     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 60       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 1884     |
# | train/             |          |
# |    actor_loss      | 235      |
# |    critic_loss     | 1.95e+03 |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | 0.0122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1783     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.9     |
# |    ep_rew_mean     | -993     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 59       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2013     |
# | train/             |          |
# |    actor_loss      | 202      |
# |    critic_loss     | 1.52e+03 |
# |    ent_coef        | 0.889    |
# |    ent_coef_loss   | -0.00499 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | -994     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 59       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 2140     |
# | train/             |          |
# |    actor_loss      | 233      |
# |    critic_loss     | 2.52e+03 |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.00835 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2039     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.3     |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 59       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2260     |
# | train/             |          |
# |    actor_loss      | 257      |
# |    critic_loss     | 1.32e+03 |
# |    ent_coef        | 0.891    |
# |    ent_coef_loss   | 0.0149   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2159     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.2     |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 58       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2391     |
# | train/             |          |
# |    actor_loss      | 250      |
# |    critic_loss     | 3.06e+03 |
# |    ent_coef        | 0.897    |
# |    ent_coef_loss   | 0.0144   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2290     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.1     |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 58       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2525     |
# | train/             |          |
# |    actor_loss      | 279      |
# |    critic_loss     | 1.52e+03 |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | 0.0353   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2424     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.1     |
# |    ep_rew_mean     | -997     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 58       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 2666     |
# | train/             |          |
# |    actor_loss      | 257      |
# |    critic_loss     | 1.58e+03 |
# |    ent_coef        | 0.942    |
# |    ent_coef_loss   | -0.00724 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2565     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35       |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 58       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 2797     |
# | train/             |          |
# |    actor_loss      | 236      |
# |    critic_loss     | 1.07e+03 |
# |    ent_coef        | 0.97     |
# |    ent_coef_loss   | 0.00141  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2696     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35        |
# |    ep_rew_mean     | -995      |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 57        |
# |    time_elapsed    | 50        |
# |    total_timesteps | 2936      |
# | train/             |           |
# |    actor_loss      | 322       |
# |    critic_loss     | 1.27e+03  |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | -0.000407 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2835      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.9     |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 57       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 3074     |
# | train/             |          |
# |    actor_loss      | 293      |
# |    critic_loss     | 798      |
# |    ent_coef        | 1.03     |
# |    ent_coef_loss   | -0.0244  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2973     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.9     |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 57       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 3213     |
# | train/             |          |
# |    actor_loss      | 350      |
# |    critic_loss     | 3.03e+03 |
# |    ent_coef        | 1.06     |
# |    ent_coef_loss   | -0.0222  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3112     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | -997     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 57       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 3344     |
# | train/             |          |
# |    actor_loss      | 319      |
# |    critic_loss     | 1.8e+03  |
# |    ent_coef        | 1.08     |
# |    ent_coef_loss   | -0.0267  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3243     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 57       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 3482     |
# | train/             |          |
# |    actor_loss      | 325      |
# |    critic_loss     | 888      |
# |    ent_coef        | 1.09     |
# |    ent_coef_loss   | 0.0127   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3381     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 57       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 3616     |
# | train/             |          |
# |    actor_loss      | 376      |
# |    critic_loss     | 1.36e+03 |
# |    ent_coef        | 1.09     |
# |    ent_coef_loss   | 0.00761  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3515     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 56       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 3754     |
# | train/             |          |
# |    actor_loss      | 379      |
# |    critic_loss     | 1e+03    |
# |    ent_coef        | 1.07     |
# |    ent_coef_loss   | 0.0151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3653     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 56       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 3897     |
# | train/             |          |
# |    actor_loss      | 398      |
# |    critic_loss     | 2.34e+03 |
# |    ent_coef        | 1.04     |
# |    ent_coef_loss   | 0.009    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3796     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.2     |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 56       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 4036     |
# | train/             |          |
# |    actor_loss      | 392      |
# |    critic_loss     | 1.3e+03  |
# |    ent_coef        | 0.992    |
# |    ent_coef_loss   | -0.00244 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3935     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34       |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 56       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 4175     |
# | train/             |          |
# |    actor_loss      | 376      |
# |    critic_loss     | 757      |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.0431  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4074     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.9     |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 56       |
# |    time_elapsed    | 76       |
# |    total_timesteps | 4313     |
# | train/             |          |
# |    actor_loss      | 421      |
# |    critic_loss     | 1.66e+03 |
# |    ent_coef        | 0.879    |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4212     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.1     |
# |    ep_rew_mean     | -994     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 56       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 4464     |
# | train/             |          |
# |    actor_loss      | 465      |
# |    critic_loss     | 2.6e+03  |
# |    ent_coef        | 0.82     |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4363     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.2     |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 56       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | 446      |
# |    critic_loss     | 1.24e+03 |
# |    ent_coef        | 0.773    |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.7     |
# |    ep_rew_mean     | -990     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 56       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 4766     |
# | train/             |          |
# |    actor_loss      | 482      |
# |    critic_loss     | 1.53e+03 |
# |    ent_coef        | 0.725    |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4665     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -986     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 56       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 4950     |
# | train/             |          |
# |    actor_loss      | 516      |
# |    critic_loss     | 1.11e+03 |
# |    ent_coef        | 0.684    |
# |    ent_coef_loss   | -0.302   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4849     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.1     |
# |    ep_rew_mean     | -987     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 56       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 5134     |
# | train/             |          |
# |    actor_loss      | 498      |
# |    critic_loss     | 1.52e+03 |
# |    ent_coef        | 0.65     |
# |    ent_coef_loss   | -0.316   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5033     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.1     |
# |    ep_rew_mean     | -987     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 55       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 5349     |
# | train/             |          |
# |    actor_loss      | 503      |
# |    critic_loss     | 749      |
# |    ent_coef        | 0.615    |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5248     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.6     |
# |    ep_rew_mean     | -989     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 55       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 5540     |
# | train/             |          |
# |    actor_loss      | 526      |
# |    critic_loss     | 1.87e+03 |
# |    ent_coef        | 0.587    |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5439     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.6     |
# |    ep_rew_mean     | -989     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 55       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 5770     |
# | train/             |          |
# |    actor_loss      | 545      |
# |    critic_loss     | 1.94e+03 |
# |    ent_coef        | 0.567    |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5669     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.9     |
# |    ep_rew_mean     | -989     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 55       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 5930     |
# | train/             |          |
# |    actor_loss      | 541      |
# |    critic_loss     | 1.37e+03 |
# |    ent_coef        | 0.553    |
# |    ent_coef_loss   | -0.0644  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5829     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -989     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 55       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 6181     |
# | train/             |          |
# |    actor_loss      | 553      |
# |    critic_loss     | 787      |
# |    ent_coef        | 0.536    |
# |    ent_coef_loss   | -0.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -986     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 55       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 6412     |
# | train/             |          |
# |    actor_loss      | 538      |
# |    critic_loss     | 816      |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.6     |
# |    ep_rew_mean     | -983     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 55       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 6581     |
# | train/             |          |
# |    actor_loss      | 575      |
# |    critic_loss     | 645      |
# |    ent_coef        | 0.517    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6480     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.3     |
# |    ep_rew_mean     | -982     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 55       |
# |    time_elapsed    | 122      |
# |    total_timesteps | 6792     |
# | train/             |          |
# |    actor_loss      | 528      |
# |    critic_loss     | 1.34e+03 |
# |    ent_coef        | 0.513    |
# |    ent_coef_loss   | 0.0208   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6691     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.5     |
# |    ep_rew_mean     | -983     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 55       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 7043     |
# | train/             |          |
# |    actor_loss      | 561      |
# |    critic_loss     | 511      |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | 0.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6942     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.4     |
# |    ep_rew_mean     | -983     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 55       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 7376     |
# | train/             |          |
# |    actor_loss      | 575      |
# |    critic_loss     | 904      |
# |    ent_coef        | 0.5      |
# |    ent_coef_loss   | -0.131   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7275     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.2     |
# |    ep_rew_mean     | -981     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 55       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 7597     |
# | train/             |          |
# |    actor_loss      | 558      |
# |    critic_loss     | 714      |
# |    ent_coef        | 0.492    |
# |    ent_coef_loss   | 0.0318   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.2     |
# |    ep_rew_mean     | -980     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 55       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 7935     |
# | train/             |          |
# |    actor_loss      | 588      |
# |    critic_loss     | 1.26e+03 |
# |    ent_coef        | 0.483    |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7834     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -975     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 55       |
# |    time_elapsed    | 149      |
# |    total_timesteps | 8205     |
# | train/             |          |
# |    actor_loss      | 555      |
# |    critic_loss     | 505      |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -0.137   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8104     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.4     |
# |    ep_rew_mean     | -976     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 54       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 8519     |
# | train/             |          |
# |    actor_loss      | 586      |
# |    critic_loss     | 967      |
# |    ent_coef        | 0.459    |
# |    ent_coef_loss   | -0.0255  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8418     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52       |
# |    ep_rew_mean     | -974     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 54       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 8816     |
# | train/             |          |
# |    actor_loss      | 565      |
# |    critic_loss     | 469      |
# |    ent_coef        | 0.442    |
# |    ent_coef_loss   | -0.0679  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8715     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.6     |
# |    ep_rew_mean     | -972     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 54       |
# |    time_elapsed    | 166      |
# |    total_timesteps | 9116     |
# | train/             |          |
# |    actor_loss      | 586      |
# |    critic_loss     | 459      |
# |    ent_coef        | 0.425    |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9015     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.8     |
# |    ep_rew_mean     | -971     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 54       |
# |    time_elapsed    | 171      |
# |    total_timesteps | 9381     |
# | train/             |          |
# |    actor_loss      | 625      |
# |    critic_loss     | 1.41e+03 |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | -0.0493  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9280     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.6     |
# |    ep_rew_mean     | -971     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 54       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 9795     |
# | train/             |          |
# |    actor_loss      | 604      |
# |    critic_loss     | 1.31e+03 |
# |    ent_coef        | 0.404    |
# |    ent_coef_loss   | 0.0302   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9694     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.1     |
# |    ep_rew_mean     | -969     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 54       |
# |    time_elapsed    | 184      |
# |    total_timesteps | 10081    |
# | train/             |          |
# |    actor_loss      | 595      |
# |    critic_loss     | 1.08e+03 |
# |    ent_coef        | 0.397    |
# |    ent_coef_loss   | -0.103   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9980     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61       |
# |    ep_rew_mean     | -970     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 54       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 10416    |
# | train/             |          |
# |    actor_loss      | 585      |
# |    critic_loss     | 1.38e+03 |
# |    ent_coef        | 0.389    |
# |    ent_coef_loss   | 0.0225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10315    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.4     |
# |    ep_rew_mean     | -971     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 54       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 10802    |
# | train/             |          |
# |    actor_loss      | 616      |
# |    critic_loss     | 588      |
# |    ent_coef        | 0.385    |
# |    ent_coef_loss   | -0.205   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10701    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.3     |
# |    ep_rew_mean     | -970     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 54       |
# |    time_elapsed    | 204      |
# |    total_timesteps | 11129    |
# | train/             |          |
# |    actor_loss      | 605      |
# |    critic_loss     | 423      |
# |    ent_coef        | 0.39     |
# |    ent_coef_loss   | -0.315   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11028    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.2     |
# |    ep_rew_mean     | -972     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 54       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 11384    |
# | train/             |          |
# |    actor_loss      | 617      |
# |    critic_loss     | 1e+03    |
# |    ent_coef        | 0.392    |
# |    ent_coef_loss   | 0.0595   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11283    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69       |
# |    ep_rew_mean     | -973     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 54       |
# |    time_elapsed    | 218      |
# |    total_timesteps | 11849    |
# | train/             |          |
# |    actor_loss      | 651      |
# |    critic_loss     | 675      |
# |    ent_coef        | 0.397    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11748    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.4     |
# |    ep_rew_mean     | -972     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 54       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 12173    |
# | train/             |          |
# |    actor_loss      | 617      |
# |    critic_loss     | 292      |
# |    ent_coef        | 0.404    |
# |    ent_coef_loss   | 0.0522   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12072    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.3     |
# |    ep_rew_mean     | -971     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 54       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 12775    |
# | train/             |          |
# |    actor_loss      | 612      |
# |    critic_loss     | 795      |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | 0.0984   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12674    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.6     |
# |    ep_rew_mean     | -972     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 54       |
# |    time_elapsed    | 241      |
# |    total_timesteps | 13096    |
# | train/             |          |
# |    actor_loss      | 608      |
# |    critic_loss     | 376      |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12995    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.8     |
# |    ep_rew_mean     | -963     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 54       |
# |    time_elapsed    | 249      |
# |    total_timesteps | 13555    |
# | train/             |          |
# |    actor_loss      | 622      |
# |    critic_loss     | 357      |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0173  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13454    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.6     |
# |    ep_rew_mean     | -964     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 54       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 13987    |
# | train/             |          |
# |    actor_loss      | 602      |
# |    critic_loss     | 423      |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.151    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13886    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | -965     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 54       |
# |    time_elapsed    | 269      |
# |    total_timesteps | 14587    |
# | train/             |          |
# |    actor_loss      | 597      |
# |    critic_loss     | 314      |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | -0.149   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14486    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.3     |
# |    ep_rew_mean     | -956     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 54       |
# |    time_elapsed    | 281      |
# |    total_timesteps | 15245    |
# | train/             |          |
# |    actor_loss      | 618      |
# |    critic_loss     | 324      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | 0.0779   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15144    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.7     |
# |    ep_rew_mean     | -947     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 54       |
# |    time_elapsed    | 294      |
# |    total_timesteps | 15950    |
# | train/             |          |
# |    actor_loss      | 587      |
# |    critic_loss     | 206      |
# |    ent_coef        | 0.407    |
# |    ent_coef_loss   | 0.131    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15849    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -928     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 54       |
# |    time_elapsed    | 311      |
# |    total_timesteps | 16882    |
# | train/             |          |
# |    actor_loss      | 578      |
# |    critic_loss     | 263      |
# |    ent_coef        | 0.39     |
# |    ent_coef_loss   | 0.126    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16781    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -919     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 54       |
# |    time_elapsed    | 327      |
# |    total_timesteps | 17692    |
# | train/             |          |
# |    actor_loss      | 595      |
# |    critic_loss     | 738      |
# |    ent_coef        | 0.39     |
# |    ent_coef_loss   | -0.0448  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17591    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -919     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 54       |
# |    time_elapsed    | 343      |
# |    total_timesteps | 18583    |
# | train/             |          |
# |    actor_loss      | 577      |
# |    critic_loss     | 218      |
# |    ent_coef        | 0.401    |
# |    ent_coef_loss   | -0.0511  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18482    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -893     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 54       |
# |    time_elapsed    | 360      |
# |    total_timesteps | 19518    |
# | train/             |          |
# |    actor_loss      | 561      |
# |    critic_loss     | 105      |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19417    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -856     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 54       |
# |    time_elapsed    | 378      |
# |    total_timesteps | 20478    |
# | train/             |          |
# |    actor_loss      | 533      |
# |    critic_loss     | 505      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 0.0737   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20377    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -821     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 54       |
# |    time_elapsed    | 396      |
# |    total_timesteps | 21438    |
# | train/             |          |
# |    actor_loss      | 531      |
# |    critic_loss     | 156      |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | 0.0952   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21337    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -781     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 54       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 22398    |
# | train/             |          |
# |    actor_loss      | 513      |
# |    critic_loss     | 105      |
# |    ent_coef        | 0.424    |
# |    ent_coef_loss   | -0.103   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22297    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | -743     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 54       |
# |    time_elapsed    | 431      |
# |    total_timesteps | 23358    |
# | train/             |          |
# |    actor_loss      | 506      |
# |    critic_loss     | 273      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23257    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | -707     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 54       |
# |    time_elapsed    | 449      |
# |    total_timesteps | 24318    |
# | train/             |          |
# |    actor_loss      | 452      |
# |    critic_loss     | 233      |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | -0.126   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24217    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | -669     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 54       |
# |    time_elapsed    | 467      |
# |    total_timesteps | 25278    |
# | train/             |          |
# |    actor_loss      | 474      |
# |    critic_loss     | 708      |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | -0.144   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25177    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | -630     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 54       |
# |    time_elapsed    | 485      |
# |    total_timesteps | 26238    |
# | train/             |          |
# |    actor_loss      | 447      |
# |    critic_loss     | 602      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -0.064   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26137    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | -602     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 54       |
# |    time_elapsed    | 502      |
# |    total_timesteps | 27175    |
# | train/             |          |
# |    actor_loss      | 452      |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.407    |
# |    ent_coef_loss   | 0.299    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27074    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# ...
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 951      |
# | time/              |          |
# |    episodes        | 4296     |
# |    fps             | 46       |
# |    time_elapsed    | 20966    |
# |    total_timesteps | 981191   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 143      |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -0.0809  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 981090   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 952      |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 46       |
# |    time_elapsed    | 20984    |
# |    total_timesteps | 982151   |
# | train/             |          |
# |    actor_loss      | -213     |
# |    critic_loss     | 71.6     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | 0.000149 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 982050   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 951      |
# | time/              |          |
# |    episodes        | 4304     |
# |    fps             | 46       |
# |    time_elapsed    | 21002    |
# |    total_timesteps | 983111   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 66.4     |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | 0.315    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 983010   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 955      |
# | time/              |          |
# |    episodes        | 4308     |
# |    fps             | 46       |
# |    time_elapsed    | 21022    |
# |    total_timesteps | 984071   |
# | train/             |          |
# |    actor_loss      | -232     |
# |    critic_loss     | 524      |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 983970   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 959      |
# | time/              |          |
# |    episodes        | 4312     |
# |    fps             | 46       |
# |    time_elapsed    | 21041    |
# |    total_timesteps | 985031   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -0.461   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 984930   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 963      |
# | time/              |          |
# |    episodes        | 4316     |
# |    fps             | 46       |
# |    time_elapsed    | 21060    |
# |    total_timesteps | 985991   |
# | train/             |          |
# |    actor_loss      | -225     |
# |    critic_loss     | 137      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.00594  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 985890   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 962      |
# | time/              |          |
# |    episodes        | 4320     |
# |    fps             | 46       |
# |    time_elapsed    | 21080    |
# |    total_timesteps | 986951   |
# | train/             |          |
# |    actor_loss      | -231     |
# |    critic_loss     | 508      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 986850   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 966      |
# | time/              |          |
# |    episodes        | 4324     |
# |    fps             | 46       |
# |    time_elapsed    | 21100    |
# |    total_timesteps | 987911   |
# | train/             |          |
# |    actor_loss      | -233     |
# |    critic_loss     | 347      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | 0.169    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 987810   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 966      |
# | time/              |          |
# |    episodes        | 4328     |
# |    fps             | 46       |
# |    time_elapsed    | 21120    |
# |    total_timesteps | 988871   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 999      |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -0.413   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 988770   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 957      |
# | time/              |          |
# |    episodes        | 4332     |
# |    fps             | 46       |
# |    time_elapsed    | 21140    |
# |    total_timesteps | 989831   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 377      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.216    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 989730   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 962      |
# | time/              |          |
# |    episodes        | 4336     |
# |    fps             | 46       |
# |    time_elapsed    | 21161    |
# |    total_timesteps | 990791   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 94.7     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.347    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 990690   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 967      |
# | time/              |          |
# |    episodes        | 4340     |
# |    fps             | 46       |
# |    time_elapsed    | 21181    |
# |    total_timesteps | 991751   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 449      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -0.268   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 991650   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 967      |
# | time/              |          |
# |    episodes        | 4344     |
# |    fps             | 46       |
# |    time_elapsed    | 21200    |
# |    total_timesteps | 992711   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 198      |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -0.364   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 992610   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 966      |
# | time/              |          |
# |    episodes        | 4348     |
# |    fps             | 46       |
# |    time_elapsed    | 21221    |
# |    total_timesteps | 993671   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 639      |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | 0.254    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 993570   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 969      |
# | time/              |          |
# |    episodes        | 4352     |
# |    fps             | 46       |
# |    time_elapsed    | 21241    |
# |    total_timesteps | 994631   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 50.8     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 994530   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 967      |
# | time/              |          |
# |    episodes        | 4356     |
# |    fps             | 46       |
# |    time_elapsed    | 21263    |
# |    total_timesteps | 995591   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 494      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.00989 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995490   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 968      |
# | time/              |          |
# |    episodes        | 4360     |
# |    fps             | 46       |
# |    time_elapsed    | 21290    |
# |    total_timesteps | 996551   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 41.9     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.164    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996450   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 970      |
# | time/              |          |
# |    episodes        | 4364     |
# |    fps             | 46       |
# |    time_elapsed    | 21311    |
# |    total_timesteps | 997511   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 62.5     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.174   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997410   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 967      |
# | time/              |          |
# |    episodes        | 4368     |
# |    fps             | 46       |
# |    time_elapsed    | 21332    |
# |    total_timesteps | 998471   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 111      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.166   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998370   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 973      |
# | time/              |          |
# |    episodes        | 4372     |
# |    fps             | 46       |
# |    time_elapsed    | 21352    |
# |    total_timesteps | 999431   |
# | train/             |          |
# |    actor_loss      | -230     |
# |    critic_loss     | 383      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -0.318   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999330   |
# ---------------------------------
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11284\3770899266.py in <module>
#      32
#      33 # Train the agent
# ---> 34 model.learn(
#      35     total_timesteps=training_steps,
#      36     callback=[
#
# ~\anaconda3\lib\site-packages\stable_baselines3\sac\sac.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297     ) -> SelfSAC:
#     298
# --> 299         return super().learn(
#     300             total_timesteps=total_timesteps,
#     301             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     332
#     333         while self.num_timesteps < total_timesteps:
# --> 334             rollout = self.collect_rollouts(
#     335                 self.env,
#     336                 train_freq=self.train_freq,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     573             callback.update_locals(locals())
#     574             # Only stop training if return value is False, not when it is None.
# --> 575             if callback.on_step() is False:
#     576                 return RolloutReturn(num_collected_steps * env.num_envs, num_collected_episodes, continue_training=False)
#     577
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\callbacks.py in on_step(self)
#      98         self.num_timesteps = self.model.num_timesteps
#      99
# --> 100         return self._on_step()
#     101
#     102     def on_training_end(self) -> None:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\callbacks.py in _on_step(self)
#     202         for callback in self.callbacks:
#     203             # Return False (stop training) if at least one callback returns False
# --> 204             continue_training = callback.on_step() and continue_training
#     205         return continue_training
#     206
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\callbacks.py in on_step(self)
#      98         self.num_timesteps = self.model.num_timesteps
#      99
# --> 100         return self._on_step()
#     101
#     102     def on_training_end(self) -> None:
#
# ~\anaconda3\lib\site-packages\wandb\integration\sb3\sb3.py in _on_step(self)
#     140             if self.model_save_path is not None:
#     141                 if self.n_calls % self.model_save_freq == 0:
# --> 142                     self.save_model()
#     143         return True
#     144
#
# ~\anaconda3\lib\site-packages\wandb\integration\sb3\sb3.py in save_model(self)
#     149     def save_model(self) -> None:
#     150         self.model.save(self.path)
# --> 151         wandb.save(self.path, base_path=self.model_save_path)
#     152         if self.verbose > 1:
#     153             logger.info(f"Saving model checkpoint to {self.path}")
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in wrapper_fn(self, *args, **kwargs)
#     368             def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     369                 if not getattr(self, "_is_finished", False):
# --> 370                     return func(self, *args, **kwargs)
#     371
#     372                 default_message = (
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in wrapper(self, *args, **kwargs)
#     358                     raise e
#     359                 cls._is_attaching = ""
# --> 360             return func(self, *args, **kwargs)
#     361
#     362         return wrapper
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in save(self, glob_str, base_path, policy)
#    1822             return True
#    1823
# -> 1824         return self._save(glob_str, base_path, policy)
#    1825
#    1826     def _save(
#
# ~\anaconda3\lib\site-packages\wandb\sdk\wandb_run.py in _save(self, glob_str, base_path, policy)
#    1876                 os.symlink(abs_path, wandb_path)
#    1877             elif not os.path.exists(wandb_path):
# -> 1878                 os.symlink(abs_path, wandb_path)
#    1879             files.append(wandb_path)
#    1880         if warn:
#
# OSError: [WinError 1314] A required privilege is not held by the client: 'C:\\Users\\AVISH\\models\\nc0cqlss\\model.zip' -> 'C:\\Users\\AVISH\\wandb\\run-20231210_143604-nc0cqlss\\files\\model.zip'

# %% [markdown]
# ## TEST TRAINED AGENT IN THE ENVIRONMENT

# %%
import torch as th
from stable_baselines3 import SAC
MODEL_PATH =r"C:\Users\AVISH\models\9ygbjh9i\model.zip"

# Create and wrap the environment
env = droneEnv(True, False)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs = env.reset()
    done = False
    episode_reward = 0
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        episode_reward += reward
    print("Episode reward", episode_reward)
    env.render("yes")

# %%
model.tau
# Out:
# 0.005
